# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame({"Variabe":["F1", "F2", "F3", "F4","F5","F6","F7", "F8", "F9", "F10","F11","F12","F13"],
                 "G":[0.0767,0.0300,0.0300,0.0767,0.0767,0.0300,0.0300,0.0300,0.0300,0.0300,0.0300,0.0300,0.5000],
                 "F":[0.0300,0.0300,0.1729,0.0300,0.1357,0.0300,0.0300,0.0300,0.0300,0.0300,0.0300,0.1686,0.2529],
                 "M":[0.0655,0.0300,0.0655,0.0300,0.0655,0.0300,0.0300,0.0300,0.0636,0.0300,0.0300,0.0300,0.5000]})

# %%
df
# Out:
#    Variabe       G       F       M
# 0       F1  0.0767  0.0300  0.0655
# 1       F2  0.0300  0.0300  0.0300
# 2       F3  0.0300  0.1729  0.0655
# 3       F4  0.0767  0.0300  0.0300
# 4       F5  0.0767  0.1357  0.0655
# 5       F6  0.0300  0.0300  0.0300
# 6       F7  0.0300  0.0300  0.0300
# 7       F8  0.0300  0.0300  0.0300
# 8       F9  0.0300  0.0300  0.0636
# 9      F10  0.0300  0.0300  0.0300
# 10     F11  0.0300  0.0300  0.0300
# 11     F12  0.0300  0.1686  0.0300
# 12     F13  0.5000  0.2529  0.5000

# %%
plt.figure()
ax=sns.barplot(data=df, x="Variabe", y="G", label="G")
ax.bar_label(ax.containers[0], fontsize=8)
plt.show()

# %%
plt.figure()
ax=sns.barplot(data=df, x="Variabe", y="M", label="M",color='orange')
ax.bar_label(ax.containers[0], fontsize=8)
plt.show()

# %%
plt.figure()
ax=sns.barplot(data=df, x="Variabe", y="F", label="F",color='green')
ax.bar_label(ax.containers[0], fontsize=8)
plt.show()
